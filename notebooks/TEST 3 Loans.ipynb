# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.feature_selection import SelectPercentile, chi2

# %%
test_path = 'C:/Users/diego/OneDrive/Escritorio/mlops_projects/mlops/loan_appro_ml_service/artifacts/test.csv'
train_path = 'C:/Users/diego/OneDrive/Escritorio/mlops_projects/mlops/loan_appro_ml_service/artifacts/train.csv'

# %%
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
train_df.head(20)
# Out:
#     loan_amnt        term  int_rate  installment sub_grade  \
# 0     25000.0   36 months      8.39       787.92        A5
# 1     12000.0   36 months      7.89       375.43        A5
# 2     23200.0   60 months     13.99       539.71        C4
# 3     16800.0   60 months     15.31       402.41        C2
# 4     18000.0   36 months      6.03       547.84        A1
# 5      7800.0   36 months     18.25       282.97        E1
# 6      2800.0   36 months     16.78        99.53        C5
# 7     21325.0   60 months     15.61       514.18        D1
# 8     11700.0   60 months     28.99       371.31        G5
# 9     10000.0   36 months      6.97       308.64        A2
# 10    25450.0   36 months     10.16       823.12        B1
# 11     9500.0   36 months     15.88       333.43        C4
# 12    12000.0   60 months     11.49       263.86        B4
# 13    35000.0   36 months     23.28      1359.96        F2
# 14    15000.0   36 months     13.35       507.95        C2
# 15     1000.0   36 months     22.40        38.40        E3
# 16     9600.0   36 months      7.89       300.35        A5
# 17    28425.0   36 months     21.99      1085.42        F1
# 18    28475.0   36 months     19.99      1058.09        D4
# 19     9000.0   36 months     12.12       299.45        B3
#
#                purpose home_ownership  annual_inc verification_status    dti  \
# 0   debt_consolidation           RENT     85000.0     Source Verified  11.03
# 1   debt_consolidation       MORTGAGE    124000.0        Not Verified  10.82
# 2          credit_card       MORTGAGE    140000.0     Source Verified  15.25
# 3   debt_consolidation       MORTGAGE     82000.0     Source Verified  14.24
# 4   debt_consolidation           RENT    220000.0     Source Verified  12.29
# 5          credit_card       MORTGAGE     85000.0            Verified  25.91
# 6     home_improvement       MORTGAGE     80000.0        Not Verified  19.20
# 7   debt_consolidation       MORTGAGE     47444.0            Verified  15.10
# 8   debt_consolidation           RENT     35000.0     Source Verified  20.13
# 9   debt_consolidation            OWN     40000.0        Not Verified  18.54
# 10  debt_consolidation       MORTGAGE    180000.0            Verified   9.25
# 11  debt_consolidation            OWN     96000.0     Source Verified  16.63
# 12               other           RENT     53060.0     Source Verified  18.18
# 13  debt_consolidation           RENT     98000.0            Verified  29.64
# 14  debt_consolidation       MORTGAGE    107000.0     Source Verified  13.67
# 15               other           RENT     40000.0        Not Verified  26.25
# 16  debt_consolidation       MORTGAGE     85000.0     Source Verified   6.07
# 17  debt_consolidation       MORTGAGE     79000.0     Source Verified  18.15
# 18  debt_consolidation       MORTGAGE     75000.0     Source Verified  32.51
# 19  debt_consolidation           RENT     83000.0        Not Verified  24.48
#
#     open_acc  pub_rec  revol_bal  revol_util  total_acc initial_list_status  \
# 0        9.0      0.0    17943.0        37.1       22.0                   w
# 1       14.0      0.0    23020.0        46.3       30.0                   w
# 2       14.0      1.0    33270.0        53.5       41.0                   w
# 3       13.0      0.0    10634.0        72.3       40.0                   f
# 4        8.0      4.0    36989.0        60.5       12.0                   w
# 5       23.0      1.0    11857.0        56.2       57.0                   w
# 6        9.0      0.0    16263.0        86.0       13.0                   f
# 7        8.0      0.0    22034.0        61.0       19.0                   f
# 8       12.0      0.0    15669.0        58.5       25.0                   w
# 9       14.0      0.0    11127.0        20.0       33.0                   f
# 10      26.0      3.0    12801.0        19.2       36.0                   f
# 11       8.0      1.0     8496.0        94.4       30.0                   w
# 12      14.0      0.0    10655.0        28.8       20.0                   f
# 13       7.0      0.0    17667.0        94.5       26.0                   w
# 14       7.0      0.0    26266.0        88.7       20.0                   f
# 15      10.0      0.0    16163.0        85.1       24.0                   f
# 16      13.0      0.0    13323.0        26.0       27.0                   w
# 17       9.0      0.0    30844.0        93.2       20.0                   f
# 18      14.0      0.0     6510.0        25.4       39.0                   f
# 19      21.0      0.0    29433.0        50.1       59.0                   f
#
#    application_type  mort_acc  pub_rec_bankruptcies  loan_status
# 0        INDIVIDUAL       4.0                   0.0            1
# 1        INDIVIDUAL       3.0                   0.0            1
# 2        INDIVIDUAL       2.0                   0.0            1
# 3        INDIVIDUAL       2.0                   0.0            0
# 4        INDIVIDUAL       0.0                   0.0            1
# 5        INDIVIDUAL       3.0                   1.0            0
# 6        INDIVIDUAL       1.0                   0.0            0
# 7        INDIVIDUAL       1.0                   0.0            0
# 8        INDIVIDUAL       4.0                   0.0            0
# 9        INDIVIDUAL       0.0                   0.0            1
# 10       INDIVIDUAL       7.0                   0.0            1
# 11       INDIVIDUAL       2.0                   0.0            1
# 12       INDIVIDUAL       NaN                   0.0            1
# 13       INDIVIDUAL       0.0                   0.0            1
# 14       INDIVIDUAL       4.0                   0.0            1
# 15       INDIVIDUAL       0.0                   0.0            0
# 16       INDIVIDUAL       1.0                   0.0            1
# 17       INDIVIDUAL       1.0                   0.0            1
# 18            JOINT       4.0                   0.0            1
# 19       INDIVIDUAL       5.0                   0.0            1

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316824 entries, 0 to 316823
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             316824 non-null  float64
#  1   term                  316824 non-null  object
#  2   int_rate              316824 non-null  float64
#  3   installment           316824 non-null  float64
#  4   sub_grade             316824 non-null  object
#  5   purpose               316824 non-null  object
#  6   home_ownership        316824 non-null  object
#  7   annual_inc            316824 non-null  float64
#  8   verification_status   316824 non-null  object
#  9   dti                   316824 non-null  float64
#  10  open_acc              316824 non-null  float64
#  11  pub_rec               316824 non-null  float64
#  12  revol_bal             316824 non-null  float64
#  13  revol_util            316596 non-null  float64
#  14  total_acc             316824 non-null  float64
#  15  initial_list_status   316824 non-null  object
#  16  application_type      316824 non-null  object
#  17  mort_acc              286640 non-null  float64
#  18  pub_rec_bankruptcies  316407 non-null  float64
#  19  loan_status           316824 non-null  int64
# dtypes: float64(12), int64(1), object(7)
# memory usage: 48.3+ MB

# %%
numerical_columns = ['loan_amnt','int_rate','installment','annual_inc','dti','open_acc','pub_rec',
                     'revol_bal','total_acc','revol_util','mort_acc','pub_rec_bankruptcies']

categorical_columns = [
                'term','sub_grade','purpose', 'home_ownership','verification_status',
                'initial_list_status','application_type'
                ]

# %%
# Crear el pipeline numérico
num_pipeline = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ]
)

# Crear el pipeline categórico
cat_pipeline = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("one_hot_encoder", OneHotEncoder(sparse_output=False)),
        ("scaler", StandardScaler(with_mean=False))
    ]
)

# Crear el preprocesador usando ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num_pipeline", num_pipeline, numerical_columns),
        ("cat_pipeline", cat_pipeline, categorical_columns)
    ]
)

# %%
preprocessing_obj = preprocessor

# %%
preprocessing_obj
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['loan_amnt', 'int_rate', 'installment',
#                                   'annual_inc', 'dti', 'open_acc', 'pub_rec',
#                                   'revol_bal', 'total_acc', 'revol_util',
#                                   'mort_acc', 'pub_rec_bankruptcies']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('one_hot_encoder',
#                                                   OneHotEncoder(sparse_output=False)),
#                                                  ('scaler',
#                                                   StandardScaler(with_mean=False))]),
#                                  ['term', 'sub_grade', 'purpose',
#                                   'home_ownership', 'verification_status',
#                                   'initial_list_status', 'application_type'])])

# %%
# LABEL
target_columns_name = "loan_status"

# %%
input_feature_train_df = train_df.drop(columns=[target_columns_name], axis = 1)
target_feature_train_df = train_df[target_columns_name]

# %%
input_feature_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316824 entries, 0 to 316823
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             316824 non-null  float64
#  1   term                  316824 non-null  object
#  2   int_rate              316824 non-null  float64
#  3   installment           316824 non-null  float64
#  4   sub_grade             316824 non-null  object
#  5   purpose               316824 non-null  object
#  6   home_ownership        316824 non-null  object
#  7   annual_inc            316824 non-null  float64
#  8   verification_status   316824 non-null  object
#  9   dti                   316824 non-null  float64
#  10  open_acc              316824 non-null  float64
#  11  pub_rec               316824 non-null  float64
#  12  revol_bal             316824 non-null  float64
#  13  revol_util            316596 non-null  float64
#  14  total_acc             316824 non-null  float64
#  15  initial_list_status   316824 non-null  object
#  16  application_type      316824 non-null  object
#  17  mort_acc              286640 non-null  float64
#  18  pub_rec_bankruptcies  316407 non-null  float64
# dtypes: float64(12), object(7)
# memory usage: 45.9+ MB

# %%
input_feature_train_arr = preprocessing_obj.fit_transform(input_feature_train_df)

# %%
input_feature_train_arr
# Out:
# array([[ 1.30259488, -1.17161078,  1.42061718, ...,  0.        ,
#         23.33322173,  0.        ],
#        [-0.25273589, -1.28337356, -0.22478919, ...,  0.        ,
#         23.33322173,  0.        ],
#        [ 1.08724139,  0.08013229,  0.43051727, ...,  0.        ,
#         23.33322173,  0.        ],
#        ...,
#        [ 0.17797109, -0.31774319,  0.35077794, ...,  0.        ,
#         23.33322173,  0.        ],
#        [ 1.24576549,  0.78423777,  1.77236373, ...,  0.        ,
#         23.33322173,  0.        ],
#        [ 0.1061866 ,  0.44224368, -0.27967728, ...,  0.        ,
#         23.33322173,  0.        ]])

# %%
train_arr = np.c_[input_feature_train_arr, np.array(target_feature_train_df)]
